# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x="prep_time",y="cook_time",data=data)

plt.title("Data")
plt.show()

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/data/indian_food.csv')

# %%
sns.barplot(x="prep_time",y="cook_time",data=data)

plt.title("Data")
plt.show()

# %%
import seaborn
seaborn.set(style="whitegrid")
sns.boxplot(x="prep_time",y="cook_time",data=data)

plt.title("Data")
plt.show()

# %%
import seaborn
seaborn.set(style="whitegrid")
sns.countplot(x="prep_time",data=data)

plt.title("Data")
plt.show()

# %%
import numpy as np

# %%
np.random.seed()
n_v=np.random.randn(1000)
n_v1=pd.Series(n_v,name="Numerical Variable")
sns.histplot(data=n_v1,kde=True)
# Out:
# <Axes: xlabel='Numerical Variable', ylabel='Count'>

# %%
seaborn.pairplot(data,hue="prep_time")


plt.show()

# %%
sns.scatterplot(x="prep_time",y="cook_time",data=data)

plt.title("Data")
plt.show()

# %%
plt.title("Distribution of Sepal Width")
plt.hist(data.cook_time);

# %%
plt.title('Distribution of Sepal Width')

plt.hist([data.cook_time, data.prep_time],
         bins=np.arange(2, 5),
         stacked=True);

plt.legend(['ccok_time','prep_time']);
